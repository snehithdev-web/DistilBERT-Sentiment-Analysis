# %%
import torch

print("CUDA Available :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU :", torch.cuda.get_device_name(0))
# Out:
# CUDA Available : True
# GPU : Tesla T4

# %%
# !git clone https://github.com/snehithdev-web/DistilBERT-Sentiment-Analysis.git
# Out:
# Cloning into 'DistilBERT-Sentiment-Analysis'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 4), reused 23 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 25.30 MiB | 18.49 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !ls
# Out:
# api  data  README.md  requirements.txt	src

# %%
# !git clone https://github.com/snehithdev-web/DistilBERT-Sentiment-Analysis.git
# Out:
# Cloning into 'DistilBERT-Sentiment-Analysis'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 4), reused 23 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 25.30 MiB | 21.24 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd DistilBERT-Sentiment-Analysis
# Out:
# /content/DistilBERT-Sentiment-Analysis/DistilBERT-Sentiment-Analysis

# %%
# !ls
# Out:
# api  data  README.md  requirements.txt	src

# %%
# !mv "IMDB Dataset.csv" data/
# Out:
# mv: cannot stat 'IMDB Dataset.csv': No such file or directory

# %%
# !ls data
# Out:
# test.csv  train.csv

# %%
# !pwd
# Out:
# /content/DistilBERT-Sentiment-Analysis

# %%
# !ls
# Out:
# api  data  README.md  requirements.txt	src

# %%
# !ls
# Out:
# api  data  README.md  requirements.txt	src

# %%
# !mv "IMDB Dataset.csv" data/
# Out:
# mv: cannot stat 'IMDB Dataset.csv': No such file or directory

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
# !ls
# Out:
# api  data  README.md  requirements.txt	src

# %%
# !mv "/content/IMDB Dataset.csv" data/
# Out:
# mv: cannot stat '/content/IMDB Dataset.csv': No such file or directory

# %%
# !ls data
# Out:
# test.csv  train.csv

# %%
# !pip install -q \
torch \
transformers==4.52.4 \
datasets==3.6.0 \
accelerate \
sentencepiece \
scikit-learn \
pandas \
numpy \
tqdm \
fastapi \
uvicorn \
python-multipart

# %%
import torch
import transformers
import datasets
import huggingface_hub

print("Torch:", torch.__version__)
print("Transformers:", transformers.__version__)
print("Datasets:", datasets.__version__)
print("HF Hub:", huggingface_hub.__version__)

print("CUDA:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch: 2.6.0+cu124
# Transformers: 4.52.4
# Datasets: 3.6.0
# HF Hub: 0.36.2
# CUDA: True
# GPU: Tesla T4

# %%
# !wc -l src/config.py
# Out:
# 68 src/config.py

# %%
# !cat src/config.py
# Out:
# import os
# import torch
#
# # =====================================================
# # Paths
# # =====================================================
#
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#
# DATA_DIR = os.path.join(BASE_DIR, "data")
#
# MODEL_DIR = os.path.join(BASE_DIR, "models")
#
# PRETRAINED_MODEL_PATH = "/content/pretrained_model/distilbert_base_uncased"
#
# FULL_DATASET = os.path.join(DATA_DIR, "IMDB Dataset.csv")
#
# TRAIN_FILE = os.path.join(DATA_DIR, "train.csv")
#
# TEST_FILE = os.path.join(DATA_DIR, "test.csv")
#
# # =====================================================
# # Model
# # =====================================================
#
# MODEL_NAME = "distilbert-base-uncased"
#
# NUM_LABELS = 2
#
# MAX_LENGTH = 256
#
# # =====================================================
# # Dataset
# # =====================================================
#
# TEST_SIZE = 0.20
#
# RANDOM_STATE = 42
#
# ...

# %%
# !find . -maxdepth 2 -type f
# Out:
# ./README.md
# ./.git/description
# ./.git/packed-refs
# ./.git/index
# ./.git/HEAD
# ./.git/config
# ./.gitignore
# ./data/test.csv
# ./data/train.csv
# ./requirements.txt
# ./src/evaluate.py
# ./src/config.py
# ./src/inference.py
# ./src/train.py
# ./src/dataset.py
# ./src/predict.py
# ./src/utils.py
# ./api/main.py

# %%
# !wc -l src/config.py
# Out:
# 68 src/config.py

# %%
# !grep -n "load_dataset" src/dataset.py

# %%
# !head -40 src/dataset.py
# Out:
# import os
#
# import pandas as pd
# from sklearn.model_selection import train_test_split
#
# from datasets import Dataset
# from transformers import AutoTokenizer
#
# from config import (
#     PRETRAINED_MODEL_PATH,
#     FULL_DATASET,
#     TRAIN_FILE,
#     TEST_FILE,
#     MAX_LENGTH,
#     TEST_SIZE,
#     RANDOM_STATE,
#     DEV_MODE,
#     DEV_TRAIN_SAMPLES,
#     DEV_TEST_SAMPLES
# )
#
# # =====================================================
# # Create Train/Test CSV (First Run Only)
# # =====================================================
#
# if not os.path.exists(TRAIN_FILE) or not os.path.exists(TEST_FILE):
#
#     print("\nCreating Train/Test CSV Files...\n")
#
#     df = pd.read_csv(FULL_DATASET)
#
#     df["label"] = df["sentiment"].map({
#         "negative": 0,
#         "positive": 1
#     })
#
#     df = df[["review", "label"]]
#
#     train_df, test_df = train_test_split(
#         df,

# %%
# %cd /content
# !rm -rf DistilBERT-Sentiment-Analysis
# !git clone https://github.com/snehithdev-web/DistilBERT-Sentiment-Analysis.git
# %cd DistilBERT-Sentiment-Analysis
# Out:
# /content
# Cloning into 'DistilBERT-Sentiment-Analysis'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 4), reused 23 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 25.30 MiB | 17.37 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Updating files: 100% (13/13), done.
# /content/DistilBERT-Sentiment-Analysis

# %%
# !head -20 src/dataset.py
# Out:
# import os
#
# import pandas as pd
# from sklearn.model_selection import train_test_split
#
# from datasets import Dataset
# from transformers import AutoTokenizer
#
# from config import (
#     MODEL_NAME,
#     FULL_DATASET,
#     TRAIN_FILE,
#     TEST_FILE,
#     MAX_LENGTH,
#     TEST_SIZE,
#     RANDOM_STATE,
#     DEV_MODE,
#     DEV_TRAIN_SAMPLES,
#     DEV_TEST_SAMPLES
# )

# %%
# !cat src/config.py
# Out:
# import os
# import torch
#
# # =====================================================
# # Paths
# # =====================================================
#
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#
# DATA_DIR = os.path.join(BASE_DIR, "data")
#
# MODEL_DIR = os.path.join(BASE_DIR, "models")
#
# FULL_DATASET = os.path.join(DATA_DIR, "IMDB Dataset.csv")
#
# TRAIN_FILE = os.path.join(DATA_DIR, "train.csv")
#
# TEST_FILE = os.path.join(DATA_DIR, "test.csv")
#
# # =====================================================
# # Model
# # =====================================================
#
# MODEL_NAME = "distilbert-base-uncased"
#
# NUM_LABELS = 2
#
# MAX_LENGTH = 256
#
# # =====================================================
# # Dataset
# # =====================================================
#
# TEST_SIZE = 0.20
#
# RANDOM_STATE = 42
#
# # =====================================================
# # Development Mode
# ...

# %%
# !grep "DEV_MODE" src/config.py
# !grep "BATCH_SIZE" src/config.py
# Out:
# DEV_MODE = True
# BATCH_SIZE = 16

# %%
# !cat src/config.py | head -60
# Out:
# import os
# import torch
#
# # =====================================================
# # Paths
# # =====================================================
#
# BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#
# DATA_DIR = os.path.join(BASE_DIR, "data")
#
# MODEL_DIR = os.path.join(BASE_DIR, "models")
#
# FULL_DATASET = os.path.join(DATA_DIR, "IMDB Dataset.csv")
#
# TRAIN_FILE = os.path.join(DATA_DIR, "train.csv")
#
# TEST_FILE = os.path.join(DATA_DIR, "test.csv")
#
# # =====================================================
# # Model
# # =====================================================
#
# MODEL_NAME = "distilbert-base-uncased"
#
# NUM_LABELS = 2
#
# MAX_LENGTH = 256
#
# # =====================================================
# # Dataset
# # =====================================================
#
# TEST_SIZE = 0.20
#
# RANDOM_STATE = 42
#
# # =====================================================
# # Development Mode
# ...

# %%
# !grep "DEV_MODE" src/config.py
# !grep "BATCH_SIZE" src/config.py
# Out:
# DEV_MODE = True
# BATCH_SIZE = 16

# %%
# %%writefile src/config.py
import os
import torch

BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))

DATA_DIR = os.path.join(BASE_DIR, "data")
MODEL_DIR = os.path.join(BASE_DIR, "models")

FULL_DATASET = os.path.join(DATA_DIR, "IMDB Dataset.csv")
TRAIN_FILE = os.path.join(DATA_DIR, "train.csv")
TEST_FILE = os.path.join(DATA_DIR, "test.csv")

MODEL_NAME = "distilbert-base-uncased"
NUM_LABELS = 2
MAX_LENGTH = 256

TEST_SIZE = 0.20
RANDOM_STATE = 42

DEV_MODE = False
DEV_TRAIN_SAMPLES = 1000
DEV_TEST_SAMPLES = 200

NUM_EPOCHS = 3
BATCH_SIZE = 32
LEARNING_RATE = 2e-5
WEIGHT_DECAY = 0.01

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Overwriting src/config.py

# %%
# !grep "DEV_MODE" src/config.py
# !grep "BATCH_SIZE" src/config.py
# Out:
# DEV_MODE = False
# BATCH_SIZE = 32

# %%
# !ps -ef | grep python
# Out:
# root          65       6  1 08:35 ?        00:00:14 [python3] <defunct>
# root          66       6  0 08:35 ?        00:00:02 python3 /usr/local/bin/colab-fileshim.py
# root         113       6  0 08:35 ?        00:00:08 /usr/bin/python3 /usr/local/bin/jupyter-server --debug --transport="ipc" --ip=172.28.0.12 --ServerApp.token= --port=9000 --FileContentsManager.root_dir=/ --FileContentsManager.allow_hidden=True --ServerApp.log_format="|%(levelname)s|%(message)s" --ServerApp.iopub_data_rate_limit=1e10 --MappingKernelManager.root_dir=/content
# root        2082       1  0 08:41 ?        00:00:00 bash -c tail -n +0 -F "/root/.config/Google/DriveFS/Logs/drive_fs.txt" | python3 /opt/google/drive/drive-filter.py > "/root/.config/Google/DriveFS/Logs/timeouts.txt"
# root        2085    2082  0 08:41 ?        00:00:00 python3 /opt/google/drive/drive-filter.py
# ...

# %%
# !rm -rf ~/.cache/huggingface
# !rm -rf ./hf_model

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp "/content/drive/MyDrive/Models/distilbert_base_uncased.zip" /content/

# %%
# !ls -lh /content/distilbert_base_uncased.zip
# Out:
# -rw------- 1 root root 236M Jul 15 08:59 /content/distilbert_base_uncased.zip

# %%
# !mkdir -p /content/pretrained_model

# !unzip -o "/content/distilbert_base_uncased.zip" -d "/content/pretrained_model"
# Out:
# Archive:  /content/distilbert_base_uncased.zip
#   inflating: /content/pretrained_model/distilbert_base_uncased/config.json
#   inflating: /content/pretrained_model/distilbert_base_uncased/model.safetensors
#   inflating: /content/pretrained_model/distilbert_base_uncased/tokenizer.json
#   inflating: /content/pretrained_model/distilbert_base_uncased/tokenizer_config.json
#   inflating: /content/pretrained_model/distilbert_base_uncased/vocab.txt

# %%
# !find /content/pretrained_model -maxdepth 2 -type f
# Out:
# /content/pretrained_model/distilbert_base_uncased/tokenizer.json
# /content/pretrained_model/distilbert_base_uncased/vocab.txt
# /content/pretrained_model/distilbert_base_uncased/tokenizer_config.json
# /content/pretrained_model/distilbert_base_uncased/config.json
# /content/pretrained_model/distilbert_base_uncased/model.safetensors

# %%
# !find /content/pretrained_model -maxdepth 2 -type f
# Out:
# /content/pretrained_model/distilbert_base_uncased/tokenizer.json
# /content/pretrained_model/distilbert_base_uncased/vocab.txt
# /content/pretrained_model/distilbert_base_uncased/tokenizer_config.json
# /content/pretrained_model/distilbert_base_uncased/config.json
# /content/pretrained_model/distilbert_base_uncased/model.safetensors

# %%
# %%writefile src/config.py
import os
import torch

# =====================================================
# Paths
# =====================================================

BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))

DATA_DIR = os.path.join(BASE_DIR, "data")

MODEL_DIR = os.path.join(BASE_DIR, "models")

PRETRAINED_MODEL_PATH = "/content/pretrained_model/distilbert_base_uncased"

FULL_DATASET = os.path.join(DATA_DIR, "IMDB Dataset.csv")

TRAIN_FILE = os.path.join(DATA_DIR, "train.csv")

TEST_FILE = os.path.join(DATA_DIR, "test.csv")

# =====================================================
# Model
# =====================================================

MODEL_NAME = "distilbert-base-uncased"

NUM_LABELS = 2

MAX_LENGTH = 256

# =====================================================
# Dataset
# =====================================================

TEST_SIZE = 0.20

RANDOM_STATE = 42

# =====================================================
# Development Mode
# =====================================================

DEV_MODE = False

DEV_TRAIN_SAMPLES = 1000

DEV_TEST_SAMPLES = 200

# =====================================================
# Training
# =====================================================

NUM_EPOCHS = 3

BATCH_SIZE = 32

LEARNING_RATE = 2e-5

WEIGHT_DECAY = 0.01

# =====================================================
# Device
# =====================================================

DEVICE = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)
# Out:
# Overwriting src/config.py

# %%
# !grep "PRETRAINED_MODEL_PATH" src/config.py

# %%
# %%writefile src/dataset.py
import os

import pandas as pd
from sklearn.model_selection import train_test_split

from datasets import Dataset
from transformers import AutoTokenizer

from config import (
    PRETRAINED_MODEL_PATH,
    FULL_DATASET,
    TRAIN_FILE,
    TEST_FILE,
    MAX_LENGTH,
    TEST_SIZE,
    RANDOM_STATE,
    DEV_MODE,
    DEV_TRAIN_SAMPLES,
    DEV_TEST_SAMPLES
)

# =====================================================
# Create Train/Test CSV (First Run Only)
# =====================================================

if not os.path.exists(TRAIN_FILE) or not os.path.exists(TEST_FILE):

    print("\nCreating Train/Test CSV Files...\n")

    df = pd.read_csv(FULL_DATASET)

    df["label"] = df["sentiment"].map({
        "negative": 0,
        "positive": 1
    })

    df = df[["review", "label"]]

    train_df, test_df = train_test_split(
        df,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE,
        stratify=df["label"]
    )

    train_df.to_csv(TRAIN_FILE, index=False)
    test_df.to_csv(TEST_FILE, index=False)

# =====================================================
# Load CSV Files
# =====================================================

print("\nLoading Dataset...\n")

train_df = pd.read_csv(TRAIN_FILE)
test_df = pd.read_csv(TEST_FILE)

# =====================================================
# Convert to HuggingFace Dataset
# =====================================================

train_dataset = Dataset.from_pandas(
    train_df,
    preserve_index=False
)

test_dataset = Dataset.from_pandas(
    test_df,
    preserve_index=False
)

# =====================================================
# Development Mode
# =====================================================

if DEV_MODE:

    print("Development Mode Enabled")

    train_dataset = train_dataset.shuffle(
        seed=RANDOM_STATE
    ).select(range(DEV_TRAIN_SAMPLES))

    test_dataset = test_dataset.shuffle(
        seed=RANDOM_STATE
    ).select(range(DEV_TEST_SAMPLES))

# =====================================================
# Tokenizer
# =====================================================

print("\nLoading Tokenizer...\n")

tokenizer = AutoTokenizer.from_pretrained(
    PRETRAINED_MODEL_PATH
)

# =====================================================
# Tokenization
# =====================================================

def tokenize_function(examples):

    return tokenizer(
        examples["review"],
        truncation=True,
        padding="max_length",
        max_length=MAX_LENGTH
    )

print("Tokenizing Training Dataset...")

train_dataset = train_dataset.map(
    tokenize_function,
    batched=True
)

print("\nTokenizing Testing Dataset...")

test_dataset = test_dataset.map(
    tokenize_function,
    batched=True
)

# =====================================================
# Rename Label
# =====================================================

train_dataset = train_dataset.rename_column(
    "label",
    "labels"
)

test_dataset = test_dataset.rename_column(
    "label",
    "labels"
)

# =====================================================
# Remove Review Column
# =====================================================

train_dataset = train_dataset.remove_columns(
    ["review"]
)

test_dataset = test_dataset.remove_columns(
    ["review"]
)

# =====================================================
# Torch Format
# =====================================================

train_dataset.set_format("torch")
test_dataset.set_format("torch")

print("\nDataset Ready Successfully!")

print(f"Training Samples : {len(train_dataset)}")
print(f"Testing Samples  : {len(test_dataset)}")

# =====================================================
# Export
# =====================================================

train_valid = {
    "train": train_dataset,
    "test": test_dataset
}
# Out:
# Overwriting src/dataset.py

# %%
# !grep "PRETRAINED_MODEL_PATH" src/dataset.py
# Out:
#     PRETRAINED_MODEL_PATH,
#     PRETRAINED_MODEL_PATH

# %%
# %%writefile src/train.py
import numpy as np
from sklearn.metrics import accuracy_score
from transformers import (
    AutoModelForSequenceClassification,
    Trainer,
    TrainingArguments
)

from config import (
    PRETRAINED_MODEL_PATH,
    MODEL_DIR,
    NUM_LABELS,
    NUM_EPOCHS,
    BATCH_SIZE,
    LEARNING_RATE,
    WEIGHT_DECAY,
    DEVICE
)

from dataset import (
    train_valid,
    tokenizer
)

print("=" * 60)
print("Loading Model...")
print("=" * 60)

model = AutoModelForSequenceClassification.from_pretrained(
    PRETRAINED_MODEL_PATH,
    num_labels=NUM_LABELS
)

model.to(DEVICE)

print(f"Using Device : {DEVICE}")
print(f"Training Samples : {len(train_valid['train'])}")
print(f"Testing Samples  : {len(train_valid['test'])}")

# =====================================================
# Metrics
# =====================================================

def compute_metrics(eval_pred):

    logits, labels = eval_pred

    predictions = np.argmax(
        logits,
        axis=1
    )

    accuracy = accuracy_score(
        labels,
        predictions
    )

    return {
        "accuracy": accuracy
    }

# =====================================================
# Training Arguments
# =====================================================

training_args = TrainingArguments(

    output_dir=MODEL_DIR,

    overwrite_output_dir=True,

    num_train_epochs=NUM_EPOCHS,

    per_device_train_batch_size=BATCH_SIZE,

    per_device_eval_batch_size=BATCH_SIZE,

    learning_rate=LEARNING_RATE,

    weight_decay=WEIGHT_DECAY,

    eval_strategy="epoch",

    save_strategy="epoch",

    logging_strategy="steps",

    logging_steps=100,

    load_best_model_at_end=True,

    metric_for_best_model="accuracy",

    save_total_limit=1,

    report_to="none"
)

# =====================================================
# Trainer
# =====================================================

trainer = Trainer(

    model=model,

    args=training_args,

    train_dataset=train_valid["train"],

    eval_dataset=train_valid["test"],

    processing_class=tokenizer,

    compute_metrics=compute_metrics
)

print("\nStarting Training...\n")

trainer.train()

print("\nSaving Model...\n")

trainer.save_model(MODEL_DIR)

tokenizer.save_pretrained(MODEL_DIR)

print("=" * 60)
print("Training Completed Successfully!")
print("=" * 60)
# Out:
# Overwriting src/train.py

# %%
import torch

print("Torch Version :", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU :", torch.cuda.get_device_name(0))
# Out:
# Torch Version : 2.6.0+cu124
# CUDA Available: True
# GPU : Tesla T4

# %%
# !nvidia-smi
# Out:
# Wed Jul 15 08:59:36 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
import torchvision
import datasets

print("Torch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("Datasets:", datasets.__version__)
# Out:
# Torch: 2.6.0+cu124
# Torchvision: 0.21.0+cu124
# Datasets: 3.6.0

# %%
import torch
import torchvision

print("Torch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("CUDA:", torch.cuda.is_available())
print("VideoReader:", hasattr(torchvision.io, "VideoReader"))

from torchvision.io import VideoReader
print("VideoReader import successful")
# Out:
# Torch: 2.6.0+cu124
# Torchvision: 0.21.0+cu124
# CUDA: True
# VideoReader: True
# VideoReader import successful

# %%
# !python src/train.py
# Out:
# 2026-07-15 09:02:02.331661: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# Loading Dataset...
#
# Development Mode Enabled
#
# Loading Tokenizer...
#
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 318kB/s]
# config.json: 100% 483/483 [00:00<00:00, 3.21MB/s]
# vocab.txt: 232kB [00:00, 4.85MB/s]
# tokenizer.json: 466kB [00:00, 13.2MB/s]
# Tokenizing Training Dataset...
# Map: 100% 1000/1000 [00:00<00:00, 1176.49 examples/s]
#
# Tokenizing Testing Dataset...
# Map: 100% 200/200 [00:00<00:00, 1197.93 examples/s]
#
# Dataset Ready Successfully!
# Training Samples : 1000
# Testing Samples  : 200
# ...
# Loading Model...
# ...
# model.safetensors: 100% 268M/268M [00:01<00:00, 183MB/s]
# ...

# %%
# !python src/train.py
# Out:
# 2026-07-15 09:06:39.218449: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# Loading Dataset...
#
#
# Loading Tokenizer...
#
# Tokenizing Training Dataset...
# Map: 100% 40000/40000 [00:38<00:00, 1029.69 examples/s]
#
# Tokenizing Testing Dataset...
# Map: 100% 10000/10000 [00:10<00:00, 962.31 examples/s]
#
# Dataset Ready Successfully!
# Training Samples : 40000
# Testing Samples  : 10000
# ...
# Loading Model...
# ...
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# ...

# %%
# !ls models
# Out:
# checkpoint-3750    special_tokens_map.json  training_args.bin
# config.json	   tokenizer_config.json    vocab.txt
# model.safetensors  tokenizer.json

# %%
# !python src/evaluate.py
# Out:
# Loading Dataset...
#
#
# Loading Tokenizer...
#
# Tokenizing Training Dataset...
# Map: 100% 40000/40000 [00:39<00:00, 1008.15 examples/s]
#
# Tokenizing Testing Dataset...
# Map: 100% 10000/10000 [00:08<00:00, 1214.45 examples/s]
#
# Dataset Ready Successfully!
# Training Samples : 40000
# Testing Samples  : 10000
# ...
# Loading Trained Model...
# ...
# 2026-07-15 10:05:46.884870: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# Evaluating Model...
#
# 100% 313/313 [01:13<00:00,  4.25it/s]
#
# ...
# Accuracy : 0.9204
# ...

# %%
# !python src/predict.py
# Out:
# Loading Tokenizer...
# Loading Model...
# 2026-07-15 10:07:45.531724: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Inference Engine Ready!
# ...
# DistilBERT Sentiment Analyzer
# Type 'exit' to quit.
# ...
#
# Enter Review : This movie was absolutely fantastic.
#
# Prediction
# -------------------------
# Sentiment : Positive
# Confidence: 99.19%
#
# Enter Review : Worst movie ever made.
#
# Prediction
# -------------------------
# Sentiment : Negative
# Confidence: 99.7%
#
# Enter Review : The acting was decent but the story was slow.
#
# Prediction
# -------------------------
# Sentiment : Negative
# Confidence: 98.04%
#
# Enter Review : The movie was okay. It had some good moments but also many boring scenes.
#
# Prediction
# ...

# %%
# !zip -r distilbert_sentiment_model.zip models
# Out:
#   adding: models/ (stored 0%)
#   adding: models/checkpoint-3750/ (stored 0%)
#   adding: models/checkpoint-3750/trainer_state.json (deflated 83%)
#   adding: models/checkpoint-3750/tokenizer.json (deflated 71%)
#   adding: models/checkpoint-3750/vocab.txt (deflated 53%)
#   adding: models/checkpoint-3750/tokenizer_config.json (deflated 75%)
#   adding: models/checkpoint-3750/config.json (deflated 45%)
#   adding: models/checkpoint-3750/special_tokens_map.json (deflated 42%)
#   adding: models/checkpoint-3750/training_args.bin (deflated 52%)
#   adding: models/checkpoint-3750/optimizer.pt (deflated 13%)
#   adding: models/checkpoint-3750/model.safetensors (deflated 8%)
#   adding: models/checkpoint-3750/rng_state.pth (deflated 25%)
#   adding: models/checkpoint-3750/scheduler.pt (deflated 56%)
#   adding: models/tokenizer.json (deflated 71%)
#   adding: models/vocab.txt (deflated 53%)
#   adding: models/tokenizer_config.json (deflated 75%)
# ...

# %%
from google.colab import files
files.download("distilbert_sentiment_model.zip")
